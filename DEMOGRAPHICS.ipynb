# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns
from sklearn.linear_model import LassoCV

# %%
# Set pandas display options to show up to 100 rows
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # I - Census 2021 DEMOGRAPHICS Data
# ## a. (cleaning and converting individual state file into usable data)

# %%
# Load in Alabama DEMOGRAPHIC file for all districts
data = pd.read_csv('data/ALLCD_DP05_AL.csv', dtype={'PROFLN': str})
data.rename(columns = {'GEONAME' :'District'}, inplace=True)

# make a dictionary of PROFLN keys to TITLE values
title_dict = dict(zip(data['PROFLN'], data['TITLE']))

# convert the dictionary to dataframe and observe 
title_df = pd.DataFrame(list(title_dict.items()), columns=['PROFLN', 'TITLE'])
title_df.head(20)
# Out:
#    PROFLN                                  TITLE
# 0       0  ACS DEMOGRAPHIC AND HOUSING ESTIMATES
# 1     0.5                                    NaN
# 2     0.8                            SEX AND AGE
# 3       1                       Total population
# 4       2                                   Male
# 5       3                                 Female
# 6       4      Sex ratio (males per 100 females)
# 7     4.3                                    NaN
# 8       5                          Under 5 years
# 9       6                           5 to 9 years
# 10      7                         10 to 14 years
# 11      8                         15 to 19 years
# 12      9                         20 to 24 years
# 13     10                         25 to 34 years
# 14     11                         35 to 44 years
# 15     12                         45 to 54 years
# 16     13                         55 to 59 years
# 17     14                         60 to 64 years
# 18     15                         65 to 74 years
# 19     16                         75 to 84 years

# %% [markdown]
# ### In the above table, you can see that the PROFLN number is associated with a Title which will eventually become our columns headers.
# ### By combining titles we get more accurate information (i.e. index 4 will become a combination of PROFLN 1&2 to create the title "Total Population - Male"

# %%
title_dict
# Out:
# {'0': 'ACS DEMOGRAPHIC AND HOUSING ESTIMATES',
#  '0.5': nan,
#  '0.8': 'SEX AND AGE',
#  '1': 'Total population',
#  '2': 'Male',
#  '3': 'Female',
#  '4': 'Sex ratio (males per 100 females)',
#  '4.3': nan,
#  '5': 'Under 5 years',
#  '6': '5 to 9 years',
#  '7': '10 to 14 years',
#  '8': '15 to 19 years',
#  '9': '20 to 24 years',
#  '10': '25 to 34 years',
#  '11': '35 to 44 years',
#  '12': '45 to 54 years',
#  '13': '55 to 59 years',
#  '14': '60 to 64 years',
#  '15': '65 to 74 years',
#  '16': '75 to 84 years',
#  '17': '85 years and over',
#  '17.3': nan,
#  '18': 'Median age (years)',
#  '18.3': nan,
#  '19': 'Under 18 years',
#  '20': '16 years and over',
#  '21': '18 years and over',
#  '22': '21 years and over',
#  '23': '62 years and over',
#  '24': '65 years and over',
#  '24.3': nan,
#  '25': '18 years and over',
#  '26': 'Male',
#  '27': 'Female',
#  '28': 'Sex ratio (males per 100 females)',
#  '28.3': nan,
#  '29': '65 years and over',
#  '30': 'Male',
#  '31': 'Female',
#  '32': 'Sex ratio (males per 100 females)',
#  '32.3': nan,
#  '32.5': 'RACE',
#  '33': 'Total population',
#  '34': 'One race',
#  '35': 'Two or more races',
#  '35.3': nan,
#  '36': 'One race',
#  '37': 'White',
#  '38': 'Black or African American',
#  '39': 'American Indian and Alaska Native',
#  '40': 'Cherokee tribal grouping',
#  '41': 'Chippewa tribal grouping',
#  '42': 'Navajo tribal grouping',
#  '43': 'Sioux tribal grouping',
#  '44': 'Asian',
#  '45': 'Asian Indian',
#  '46': 'Chinese',
#  '47': 'Filipino',
#  '48': 'Japanese',
#  '49': 'Korean',
#  '50': 'Vietnamese',
#  '51': 'Other Asian',
#  '52': 'Native Hawaiian and Other Pacific Islander',
#  '53': 'Native Hawaiian',
#  '54': 'Chamorro',
#  '55': 'Samoan',
#  '56': 'Other Pacific Islander',
#  '57': 'Some other race',
#  '58': 'Two or more races',
#  '59': 'White and Black or African American',
#  '60': 'White and American Indian and Alaska Native',
#  '61': 'White and Asian',
#  '62': 'Black or African American and American Indian and Alaska Native',
#  '62.3': nan,
#  '62.5': 'Race alone or in combination with one or more other races',
#  '63': 'Total population',
#  '64': 'White',
#  '65': 'Black or African American',
#  '66': 'American Indian and Alaska Native',
#  '67': 'Asian',
#  '68': 'Native Hawaiian and Other Pacific Islander',
#  '69': 'Some other race',
#  '69.3': nan,
#  '69.5': 'HISPANIC OR LATINO AND RACE',
#  '70': 'Total population',
#  '71': 'Hispanic or Latino (of any race)',
#  '72': 'Mexican',
#  '73': 'Puerto Rican',
#  '74': 'Cuban',
#  '75': 'Other Hispanic or Latino',
#  '76': 'Not Hispanic or Latino',
#  '77': 'White alone',
#  '78': 'Black or African American alone',
#  '79': 'American Indian and Alaska Native alone',
#  '80': 'Asian alone',
#  '81': 'Native Hawaiian and Other Pacific Islander alone',
#  '82': 'Some other race alone',
#  '83': 'Two or more races',
#  '84': 'Two races including Some other race',
#  '85': 'Two races excluding Some other race, and Three or more races',
#  '85.3': nan,
#  '86': 'Total housing units',
#  '86.3': nan,
#  '86.5': 'CITIZEN, VOTING AGE POPULATION',
#  '87': 'Citizen, 18 and over population',
#  '88': 'Male',
#  '89': 'Female'}

# %%
## Combining PROFLN numbers which will become new TITLEs

# "Total Population-" Category
for i in range(2, 25):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-' + str(i)

# "Total Population- 18 years and over-" Category
for i in range(25, 29):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-25' + ('' if i == 25 else '-' + str(i))

#"Total Population- 65 years and over-" Category
for i in range(29, 33):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-29' + ('' if i == 29 else '-' + str(i))

# "RACE-" Category
for i in range(33, 37):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-' + str(i)

# "RACE- One race-" Category
for i in range(37, 58):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-36-' + str(i)

# "RACE- Two or more races-" Category
for i in range(58, 63):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-58' + ('' if i == 58 else '-' + str(i))

#"RACE- Race alone or in combination with one or more other races-" Category
for i in range(63, 70):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-62.5-' + str(i)

# 'HISPANIC OR LATINO AND RACE-" Category
for i in range(70, 86):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '69.5-' + str(i)

# 'CITIZEN, VOTING AGE POPULATION' Category
for i in range(87, 90):
    data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '86.5-' + str(i)

# %%
# Translate new profln numbers to combo titles
def translate_profln(profln):
    # split the PROFLN value into individual keys
    keys = profln.split('-')

    # translate each key from the title_dict
    titles = [str(title_dict.get(key, '')) for key in keys]

    # concat translated title strings
    translated_title = ' - '.join(title for title in titles if title)

    return translated_title

# replace TITLE values with their new names using function
data['TITLE'] = data['PROFLN'].apply(translate_profln)
data['TITLE'].value_counts()
# Out:
# TITLE
# nan                                                                                                              84
# RACE - Two or more races                                                                                         14
# RACE - One race                                                                                                  14
# Total population - 65 years and over                                                                             14
# Total population - 18 years and over                                                                             14
# RACE - One race - Native Hawaiian                                                                                 7
# RACE - Two or more races - Black or African American and American Indian and Alaska Native                        7
# RACE - One race - Other Asian                                                                                     7
# RACE - Race alone or in combination with one or more other races - Asian                                          7
# RACE - Race alone or in combination with one or more other races - American Indian and Alaska Native              7
# RACE - Race alone or in combination with one or more other races - Black or African American                      7
# RACE - Race alone or in combination with one or more other races - White                                          7
# RACE - Race alone or in combination with one or more other races - Total population                               7
# Race alone or in combination with one or more other races                                                         7
# RACE - Two or more races - White and Asian                                                                        7
# RACE - One race - Chamorro                                                                                        7
# RACE - One race - Native Hawaiian and Other Pacific Islander                                                      7
# RACE - Race alone or in combination with one or more other races - Native Hawaiian and Other Pacific Islander     7
# RACE - Two or more races - White and American Indian and Alaska Native                                            7
# RACE - Two or more races - White and Black or African American                                                    7
# RACE - One race - Some other race                                                                                 7
# RACE - One race - Other Pacific Islander                                                                          7
# RACE - One race - Samoan                                                                                          7
# ACS DEMOGRAPHIC AND HOUSING ESTIMATES                                                                             7
# RACE - Race alone or in combination with one or more other races - Some other race                                7
# RACE - One race - Korean                                                                                          7
# HISPANIC OR LATINO AND RACE - Asian alone                                                                         7
# CITIZEN, VOTING AGE POPULATION - Male                                                                             7
# CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population                                                  7
# CITIZEN, VOTING AGE POPULATION                                                                                    7
# Total housing units                                                                                               7
# HISPANIC OR LATINO AND RACE - Two races excluding Some other race, and Three or more races                        7
# HISPANIC OR LATINO AND RACE - Two races including Some other race                                                 7
# HISPANIC OR LATINO AND RACE - Two or more races                                                                   7
# HISPANIC OR LATINO AND RACE - Some other race alone                                                               7
# HISPANIC OR LATINO AND RACE - Native Hawaiian and Other Pacific Islander alone                                    7
# HISPANIC OR LATINO AND RACE - American Indian and Alaska Native alone                                             7
# HISPANIC OR LATINO AND RACE                                                                                       7
# HISPANIC OR LATINO AND RACE - Black or African American alone                                                     7
# HISPANIC OR LATINO AND RACE - White alone                                                                         7
# HISPANIC OR LATINO AND RACE - Not Hispanic or Latino                                                              7
# HISPANIC OR LATINO AND RACE - Other Hispanic or Latino                                                            7
# HISPANIC OR LATINO AND RACE - Cuban                                                                               7
# HISPANIC OR LATINO AND RACE - Puerto Rican                                                                        7
# HISPANIC OR LATINO AND RACE - Mexican                                                                             7
# HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)                                                    7
# HISPANIC OR LATINO AND RACE - Total population                                                                    7
# RACE - One race - Vietnamese                                                                                      7
# RACE - One race - Chinese                                                                                         7
# RACE - One race - Japanese                                                                                        7
# Total population - 20 to 24 years                                                                                 7
# Total population - 85 years and over                                                                              7
# Total population - 75 to 84 years                                                                                 7
# Total population - 65 to 74 years                                                                                 7
# Total population - 60 to 64 years                                                                                 7
# Total population - 55 to 59 years                                                                                 7
# Total population - 45 to 54 years                                                                                 7
# Total population - 35 to 44 years                                                                                 7
# Total population - 25 to 34 years                                                                                 7
# Total population - 15 to 19 years                                                                                 7
# Total population - Under 18 years                                                                                 7
# Total population - 10 to 14 years                                                                                 7
# Total population - 5 to 9 years                                                                                   7
# Total population - Under 5 years                                                                                  7
# Total population - Sex ratio (males per 100 females)                                                              7
# Total population - Female                                                                                         7
# Total population - Male                                                                                           7
# Total population                                                                                                  7
# SEX AND AGE                                                                                                       7
# Total population - Median age (years)                                                                             7
# Total population - 16 years and over                                                                              7
# RACE - One race - Filipino                                                                                        7
# RACE - One race - White                                                                                           7
# RACE - One race - Asian Indian                                                                                    7
# RACE - One race - Asian                                                                                           7
# RACE - One race - Sioux tribal grouping                                                                           7
# RACE - One race - Navajo tribal grouping                                                                          7
# RACE - One race - Chippewa tribal grouping                                                                        7
# RACE - One race - Cherokee tribal grouping                                                                        7
# RACE - One race - American Indian and Alaska Native                                                               7
# RACE - One race - Black or African American                                                                       7
# RACE - Total population                                                                                           7
# Total population - 21 years and over                                                                              7
# RACE                                                                                                              7
# Total population - 65 years and over - Sex ratio (males per 100 females)                                          7
# Total population - 65 years and over - Female                                                                     7
# Total population - 65 years and over - Male                                                                       7
# Total population - 18 years and over - Sex ratio (males per 100 females)                                          7
# Total population - 18 years and over - Female                                                                     7
# Total population - 18 years and over - Male                                                                       7
# Total population - 62 years and over                                                                              7
# CITIZEN, VOTING AGE POPULATION - Female                                                                           7
# Name: count, dtype: int64

# %%
# remove rows with NaN's, placeholder 'N' for 'Not Large Enough Sample Size', and placeholder '(X)'' rows
invalid_rows = data['PRF_ESTIMATE'].isin(['N', '(X)']) | data['PRF_ESTIMATE'].isna()

# filter out these rows from the Dataframe
data = data[~invalid_rows]

# %%
# remove rows of duplicate information or strong overlap

# List of PROFLN values to remove (many values are repeats from other categories and subcategories)
profln_to_remove = ['1-29', '1-25', '32.5-33', '32.5-36', '32.5-58', 
                    '32.5-62.5-63', '32.5-62.5-64', '32.5-62.5-65', 
                    '32.5-62.5-66', '32.5-62.5-67', '32.5-62.5-68', 
                    '32.5-62.5-69', '69.5-70', '69.5-76', '69.5-77', 
                    '69.5-78', '69.5-79', '69.5-80', '69.5-81', '69.5-82']

# filter the data to observe which rows we are removing
rows_to_remove = data[data['PROFLN'].isin(profln_to_remove)]
print(rows_to_remove['TITLE'])

# Remove these rows from the DataFrame
data = data[~data['PROFLN'].isin(profln_to_remove)]
# Out:
# 31                                               Total population - 18 years and over
# 36                                               Total population - 65 years and over
# 42                                                            RACE - Total population
# 46                                                                    RACE - One race
# 68                                                           RACE - Two or more races
#                                             ...
# 734                     HISPANIC OR LATINO AND RACE - Black or African American alone
# 735             HISPANIC OR LATINO AND RACE - American Indian and Alaska Native alone
# 736                                         HISPANIC OR LATINO AND RACE - Asian alone
# 737    HISPANIC OR LATINO AND RACE - Native Hawaiian and Other Pacific Islander alone
# 738                               HISPANIC OR LATINO AND RACE - Some other race alone
# Name: TITLE, Length: 138, dtype: object

# %%
# Delete margin of error columns
data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

# Some MEDIAN and MEAN values are not listed in PCT_ESTIMATE column, but are relevant
data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

# Convert all the values to numeric
data['PCT_ESTIMATE'] = data['PCT_ESTIMATE'].str.replace(',', '').astype(float)
data['PRF_ESTIMATE'] = data['PRF_ESTIMATE'].str.replace(',', '').astype(float)

data
# Out:
#     TBLID          GEOID                                            District  \
# 3    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 4    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 5    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 6    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# 8    DP05  5001800US0101  Congressional District 1 (118th Congress), Alabama
# ..    ...            ...                                                 ...
# 741  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 743  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 746  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 747  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
# 748  DP05  5001800US0107  Congressional District 7 (118th Congress), Alabama
#
#       PROFLN  \
# 3          1
# 4        1-2
# 5        1-3
# 6        1-4
# 8        1-5
# ..       ...
# 741  69.5-85
# 743       86
# 746  86.5-87
# 747  86.5-88
# 748  86.5-89
#
#                                                                                           TITLE  \
# 3                                                                              Total population
# 4                                                                       Total population - Male
# 5                                                                     Total population - Female
# 6                                          Total population - Sex ratio (males per 100 females)
# 8                                                              Total population - Under 5 years
# ..                                                                                          ...
# 741  HISPANIC OR LATINO AND RACE - Two races excluding Some other race, and Three or more races
# 743                                                                         Total housing units
# 746                            CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population
# 747                                                       CITIZEN, VOTING AGE POPULATION - Male
# 748                                                     CITIZEN, VOTING AGE POPULATION - Female
#
#      PRF_ESTIMATE  PCT_ESTIMATE
# 3        727212.0      727212.0
# 4        353457.0          48.6
# 5        373755.0          51.4
# 6            94.6          94.6
# 8         41746.0           5.7
# ..            ...           ...
# 741       14020.0           2.0
# 743      344719.0      344719.0
# 746      546972.0      546972.0
# 747      252332.0          46.1
# 748      294640.0          53.9
#
# [427 rows x 7 columns]

# %%
## Converting the long district titles to their state and district codes ('AL-01' = 'Alabama District 1')
# State Mapping
states = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
    'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
    'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
    'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA',
    'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
    'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

def format_district(district):
    # Extract the state name and district number from the district string
    match = re.search(r'Congressional District (\d+|\(at Large\)) \(118th Congress\), ([A-Za-z\s]+)', district)
    if match:
        district_num, state_name = match.groups()
        # Convert the district number to 'AL' for 'at large' districts
        if district_num == '(at Large)':
            district_num = 'AL'
        else:
            district_num = district_num.zfill(2)  # Pad single digit numbers with a leading zero
        # Convert state name to its abbreviation
        state_abbr = states.get(state_name.strip(), state_name)
        # Return the formatted district name
        return f'{state_abbr}-{district_num}'
    
# Apply the function to the 'District' column in both dataframes to replace values with their short-hand
data['Formatted_District'] = data['District'].apply(format_district)

# %%
#ensure all districts have the same number of values
data['Formatted_District'].value_counts()
# Out:
# Formatted_District
# AL-01    61
# AL-02    61
# AL-03    61
# AL-04    61
# AL-05    61
# AL-06    61
# AL-07    61
# Name: count, dtype: int64

# %%
# Pivot the dataframe separately into two dataframes with 'PRF_ESTIMATE' (raw numbers) and 'PCT_ESTIMATE' (%'s)
prf_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PRF_ESTIMATE')
pct_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PCT_ESTIMATE')

# Reset the column names after pivot
prf_estimate_df.columns = [f'{col}' for col in prf_estimate_df.columns]
pct_estimate_df.columns = [f'{col}' for col in pct_estimate_df.columns]

# Reset the index
prf_estimate_df.reset_index(inplace=True)
pct_estimate_df.reset_index(inplace=True)

prf_estimate_df
# Out:
#   Formatted_District          GEOID  \
# 0              AL-01  5001800US0101
# 1              AL-02  5001800US0102
# 2              AL-03  5001800US0103
# 3              AL-04  5001800US0104
# 4              AL-05  5001800US0105
# 5              AL-06  5001800US0106
# 6              AL-07  5001800US0107
#
#    CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                          555123.0
# 1                                                          539010.0
# 2                                                          558552.0
# 3                                                          541258.0
# 4                                                          557827.0
# 5                                                          531046.0
# 6                                                          546972.0
#
#    CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                 289663.0
# 1                                 284652.0
# 2                                 289423.0
# 3                                 280884.0
# 4                                 285421.0
# 5                                 277760.0
# 6                                 294640.0
#
#    CITIZEN, VOTING AGE POPULATION - Male  HISPANIC OR LATINO AND RACE - Cuban  \
# 0                               265460.0                               1480.0
# 1                               254358.0                                479.0
# 2                               269129.0                                766.0
# 3                               260374.0                               1322.0
# 4                               272406.0                               1481.0
# 5                               253286.0                               1180.0
# 6                               252332.0                               1024.0
#
#    HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                         25346.0
# 1                                                         29072.0
# 2                                                         22960.0
# 3                                                         52766.0
# 4                                                         41789.0
# 5                                                         36253.0
# 6                                                         29248.0
#
#    HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                14082.0
# 1                                18554.0
# 2                                11728.0
# 3                                37454.0
# 4                                20557.0
# 5                                24216.0
# 6                                18521.0
#
#    HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                  6571.0
# 1                                                  5484.0
# 2                                                  6468.0
# 3                                                 11988.0
# 4                                                 13835.0
# 5                                                  9624.0
# 6                                                  8699.0
#
#    HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                      3213.0  ...
# 1                                      4555.0  ...
# 2                                      3998.0  ...
# 3                                      2002.0  ...
# 4                                      5916.0  ...
# 5                                      1233.0  ...
# 6                                      1004.0  ...
#
#    Total population - 65 years and over - Male  \
# 0                                      61808.0
# 1                                      54456.0
# 2                                      55915.0
# 3                                      59392.0
# 4                                      54646.0
# 5                                      52246.0
# 6                                      50770.0
#
#    Total population - 65 years and over - Sex ratio (males per 100 females)  \
# 0                                                                      82.8
# 1                                                                      76.9
# 2                                                                      79.6
# 3                                                                      79.6
# 4                                                                      78.2
# 5                                                                      79.7
# 6                                                                      71.7
#
#    Total population - 75 to 84 years  Total population - 85 years and over  \
# 0                            40508.0                               12282.0
# 1                            38134.0                               12806.0
# 2                            39234.0                                8784.0
# 3                            40315.0                               12003.0
# 4                            37413.0                               12440.0
# 5                            35741.0                               11321.0
# 6                            32485.0                               12120.0
#
#    Total population - Female  Total population - Male  \
# 0                   373755.0                 353457.0
# 1                   370483.0                 345729.0
# 2                   368853.0                 352436.0
# 3                   369637.0                 353433.0
# 4                   370374.0                 359010.0
# 5                   363521.0                 342976.0
# 6                   377358.0                 338855.0
#
#    Total population - Median age (years)  \
# 0                                   41.0
# 1                                   39.0
# 2                                   40.0
# 3                                   40.5
# 4                                   40.5
# 5                                   39.6
# 6                                   37.5
#
#    Total population - Sex ratio (males per 100 females)  \
# 0                                                  94.6
# 1                                                  93.3
# 2                                                  95.5
# 3                                                  95.6
# 4                                                  96.9
# 5                                                  94.3
# 6                                                  89.8
#
#    Total population - Under 18 years  Total population - Under 5 years
# 0                           162658.0                           41746.0
# 1                           165222.0                           41997.0
# 2                           152113.0                           39510.0
# 3                           165303.0                           45914.0
# 4                           157595.0                           37683.0
# 5                           161580.0                           41408.0
# 6                           155471.0                           41833.0
#
# [7 rows x 63 columns]

# %% [markdown]
# # I - Census 2021 DEMOGRAPHICS Data
# ## b. (converting previous steps into functions to apply and join all 50 state files)

# %%
#LOAD FUNCTION

def load_and_rename_data(csv):
    data = pd.read_csv(csv, dtype={'PROFLN': str})
    data.rename(columns = {'GEONAME' :'District'}, inplace=True)
    title_dict = dict(zip(data['PROFLN'], data['TITLE']))
    return data, title_dict

# %%
#UPDATE PROFLN FUNCTION

def update_profln_values(data):
    for i in range(2, 25):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-' + str(i)
    for i in range(25, 29):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-25' + ('' if i == 25 else '-' + str(i))
    for i in range(29, 33):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '1-29' + ('' if i == 29 else '-' + str(i))
    for i in range(33, 37):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-' + str(i)
    for i in range(37, 58):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-36-' + str(i)
    for i in range(58, 63):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-58' + ('' if i == 58 else '-' + str(i))
    for i in range(63, 70):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '32.5-62.5-' + str(i)
    for i in range(70, 86):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '69.5-' + str(i)
    for i in range(87, 90):
        data.loc[data['PROFLN'] == str(i), 'PROFLN'] = '86.5-' + str(i)
    return data

# %%
## REFORM TITLES FUNCTION

def translate_profln(profln, title_dict):
    # Split the PROFLN value into keys
    keys = profln.split('-')

    # Translate each key using the title_dict, ensuring that all elements are converted to strings
    titles = [str(title_dict.get(key, '')) for key in keys]

    # Concatenate the translated titles
    translated_title = ' - '.join(title for title in titles if title)

    return translated_title

# %%
# CLEAN UP DATA AND DROP REDUNDANT INFO FUNCTION

def clean_up_data(data):
    # drop unneccessary rows and rows with placeholders
    invalid_rows = data['PRF_ESTIMATE'].isin(['N', '(X)']) | data['PRF_ESTIMATE'].isna()
    data = data[~invalid_rows]

    # The rows associated with these index markers contain duplicate data
    profln_to_remove = ['1-29', '1-25', '32.5-33', '32.5-36', '32.5-58', 
                        '32.5-62.5-63', '32.5-62.5-64', '32.5-62.5-65', 
                        '32.5-62.5-66', '32.5-62.5-67', '32.5-62.5-68', 
                        '32.5-62.5-69', '69.5-70', '69.5-76', '69.5-77', 
                        '69.5-78', '69.5-79', '69.5-80', '69.5-81', '69.5-82']
    data = data[~data['PROFLN'].isin(profln_to_remove)]

    # Delete the margin of error columns
    data = data.drop(columns=['PRF_MG_ERROR', 'PCT_MG_ERROR'])

    # Replace '(X)' values in PCT_ESTIMATE with their PRF_ESTIMATE values (average and median values, usually)
    data.loc[data['PCT_ESTIMATE'] == '(X)', 'PCT_ESTIMATE'] = data['PRF_ESTIMATE']

    # convert to numeric
    data['PCT_ESTIMATE'] = data['PCT_ESTIMATE'].str.replace(',', '').astype(float)
    data['PRF_ESTIMATE'] = data['PRF_ESTIMATE'].str.replace(',', '').astype(float)
    
    return data

# %%
# CONVERT TO STATE-DISTRICT FUNCTION

def format_districts(data):
    # Mapping of state names to abbreviations
    states = {
        'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
        'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
        'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
        'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
        'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
        'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH',
        'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
        'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA',
        'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
        'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
        'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
    }

    # function to format a single district
    def format_district(district):
        # extract the state name and district number from the district string
        match = re.search(r'Congressional District (\d+|\(at Large\)) \(118th Congress\), ([A-Za-z\s]+)', district)
        if match:
            district_num, state_name = match.groups()
            # convert the district number to 'AL' for 'at large' districts
            if district_num == '(at Large)':
                district_num = 'AL'
            else:
                district_num = district_num.zfill(2)  # pad single digit numbers with a leading zero
            # convert the state name to its abbreviation
            state_abbr = states.get(state_name.strip(), state_name)
            # return the formatted district name
            return f'{state_abbr}-{district_num}'
        else:
            return district

    # Apply the function to the District column
    data['Formatted_District'] = data['District'].apply(format_district)

    return data

# %%
## TRANSPOSE DATAFRAME FUNCTION
def reorient_dfs(data):
    # Pivot the dataframe separately for 'PRF_ESTIMATE' and 'PCT_ESTIMATE'
    prf_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PRF_ESTIMATE')
    pct_estimate_df = data.pivot_table(index=['Formatted_District', 'GEOID'], columns='TITLE', values='PCT_ESTIMATE')

    # Reset the column names after pivot
    prf_estimate_df.columns = [f'{col}' for col in prf_estimate_df.columns]
    pct_estimate_df.columns = [f'{col}' for col in pct_estimate_df.columns]

    # Reset the index
    prf_estimate_df.reset_index(inplace=True)
    pct_estimate_df.reset_index(inplace=True)

    return prf_estimate_df, pct_estimate_df

# %% [markdown]
# # I- Census 2021 DEMOGRAPHIC Data
# ## c. process all 50 states demographic files

# %%
## PROCESS ALL 50 STATES FUNCTION
def process_demographics(file_state_list):
    prf_dfs = []
    pct_dfs = []
    
    for file_state in file_state_list:
        csv, state = file_state

        data, title_dict = load_and_rename_data(csv)
        data = update_profln_values(data)
        data['TITLE'] = data['PROFLN'].apply(lambda x: translate_profln(x, title_dict))
        data = clean_up_data(data)
        data = format_districts(data)

        prf_estimate_df, pct_estimate_df = reorient_dfs(data)

        prf_dfs.append(prf_estimate_df)
        pct_dfs.append(pct_estimate_df)
    
    df_prfdemo_all = pd.concat(prf_dfs, ignore_index=True)
    df_pctdemo_all = pd.concat(pct_dfs, ignore_index=True)
    
    return df_prfdemo_all, df_pctdemo_all

# %%
file_state_list = [
 ('data/ALLCD_DP05_AK.csv', 'AK'),('data/ALLCD_DP05_AL.csv', 'AL'),('data/ALLCD_DP05_AR.csv', 'AR'),
 ('data/ALLCD_DP05_AZ.csv', 'AZ'),('data/ALLCD_DP05_CA.csv', 'CA'),('data/ALLCD_DP05_CO.csv', 'CO'),
 ('data/ALLCD_DP05_CT.csv', 'CT'),('data/ALLCD_DP05_DE.csv', 'DE'),('data/ALLCD_DP05_FL.csv', 'FL'),
 ('data/ALLCD_DP05_GA.csv', 'GA'),('data/ALLCD_DP05_HI.csv', 'HI'),('data/ALLCD_DP05_IA.csv', 'IA'),
 ('data/ALLCD_DP05_ID.csv', 'ID'),('data/ALLCD_DP05_IL.csv', 'IL'),('data/ALLCD_DP05_IN.csv', 'IN'),
 ('data/ALLCD_DP05_KS.csv', 'KS'),('data/ALLCD_DP05_KY.csv', 'KY'),('data/ALLCD_DP05_LA.csv', 'LA'),
 ('data/ALLCD_DP05_MA.csv', 'MA'),('data/ALLCD_DP05_MD.csv', 'MD'),('data/ALLCD_DP05_ME.csv', 'ME'),
 ('data/ALLCD_DP05_MI.csv', 'MI'),('data/ALLCD_DP05_MN.csv', 'MN'),('data/ALLCD_DP05_MO.csv', 'MO'),
 ('data/ALLCD_DP05_MS.csv', 'MS'),('data/ALLCD_DP05_MT.csv', 'MT'),('data/ALLCD_DP05_NC.csv', 'NC'),
 ('data/ALLCD_DP05_ND.csv', 'ND'),('data/ALLCD_DP05_NE.csv', 'NE'),('data/ALLCD_DP05_NH.csv', 'NH'),
 ('data/ALLCD_DP05_NJ.csv', 'NJ'),('data/ALLCD_DP05_NM.csv', 'NM'),('data/ALLCD_DP05_NV.csv', 'NV'),
 ('data/ALLCD_DP05_NY.csv', 'NY'),('data/ALLCD_DP05_OH.csv', 'OH'),('data/ALLCD_DP05_OK.csv', 'OK'),
 ('data/ALLCD_DP05_OR.csv', 'OR'),('data/ALLCD_DP05_PA.csv', 'PA'),('data/ALLCD_DP05_RI.csv', 'RI'),
 ('data/ALLCD_DP05_SC.csv', 'SC'),('data/ALLCD_DP05_SD.csv', 'SD'),('data/ALLCD_DP05_TN.csv', 'TN'),
 ('data/ALLCD_DP05_TX.csv', 'TX'),('data/ALLCD_DP05_UT.csv', 'UT'),('data/ALLCD_DP05_VA.csv', 'VA'),
 ('data/ALLCD_DP05_VT.csv', 'VT'),('data/ALLCD_DP05_WA.csv', 'WA'),('data/ALLCD_DP05_WI.csv', 'WI'),
 ('data/ALLCD_DP05_WV.csv', 'WV'),('data/ALLCD_DP05_WY.csv', 'WY')
]


df_prfdemo_all, df_pctdemo_all = process_demographics(file_state_list)

# %%
df_prfdemo_all
# Out:
#     Formatted_District          GEOID  \
# 0                AK-AL  5001800US0200
# 1                AL-01  5001800US0101
# 2                AL-02  5001800US0102
# 3                AL-03  5001800US0103
# 4                AL-04  5001800US0104
# ..                 ...            ...
# 430              WI-07  5001800US5507
# 431              WI-08  5001800US5508
# 432              WV-01  5001800US5401
# 433              WV-02  5001800US5402
# 434              WY-AL  5001800US5600
#
#      CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                            533852.0
# 1                                                            555123.0
# 2                                                            539010.0
# 3                                                            558552.0
# 4                                                            541258.0
# ..                                                                ...
# 430                                                          579658.0
# 431                                                          562233.0
# 432                                                          696591.0
# 433                                                          712176.0
# 434                                                          436049.0
#
#      CITIZEN, VOTING AGE POPULATION - Female  \
# 0                                   252485.0
# 1                                   289663.0
# 2                                   284652.0
# 3                                   289423.0
# 4                                   280884.0
# ..                                       ...
# 430                                 284696.0
# 431                                 281545.0
# 432                                 357316.0
# 433                                 356501.0
# 434                                 214110.0
#
#      CITIZEN, VOTING AGE POPULATION - Male  \
# 0                                 281367.0
# 1                                 265460.0
# 2                                 254358.0
# 3                                 269129.0
# 4                                 260374.0
# ..                                     ...
# 430                               294962.0
# 431                               280688.0
# 432                               339275.0
# 433                               355675.0
# 434                               221939.0
#
#      HISPANIC OR LATINO AND RACE - Cuban  \
# 0                                 3182.0
# 1                                 1480.0
# 2                                  479.0
# 3                                  766.0
# 4                                 1322.0
# ..                                   ...
# 430                                675.0
# 431                                548.0
# 432                                404.0
# 433                                491.0
# 434                                276.0
#
#      HISPANIC OR LATINO AND RACE - Hispanic or Latino (of any race)  \
# 0                                                           52291.0
# 1                                                           25346.0
# 2                                                           29072.0
# 3                                                           22960.0
# 4                                                           52766.0
# ..                                                              ...
# 430                                                         19067.0
# 431                                                         44334.0
# 432                                                          9502.0
# 433                                                         20848.0
# 434                                                         61090.0
#
#      HISPANIC OR LATINO AND RACE - Mexican  \
# 0                                  22299.0
# 1                                  14082.0
# 2                                  18554.0
# 3                                  11728.0
# 4                                  37454.0
# ..                                     ...
# 430                                11203.0
# 431                                29112.0
# 432                                 3745.0
# 433                                 7160.0
# 434                                43678.0
#
#      HISPANIC OR LATINO AND RACE - Other Hispanic or Latino  \
# 0                                                   18157.0
# 1                                                    6571.0
# 2                                                    5484.0
# 3                                                    6468.0
# 4                                                   11988.0
# ..                                                      ...
# 430                                                  5014.0
# 431                                                  7778.0
# 432                                                  3927.0
# 433                                                  9278.0
# 434                                                 15678.0
#
#      HISPANIC OR LATINO AND RACE - Puerto Rican  ...  \
# 0                                        8653.0  ...
# 1                                        3213.0  ...
# 2                                        4555.0  ...
# 3                                        3998.0  ...
# 4                                        2002.0  ...
# ..                                          ...  ...
# 430                                      2175.0  ...
# 431                                      6896.0  ...
# 432                                      1426.0  ...
# 433                                      3919.0  ...
# 434                                      1458.0  ...
#
#      Total population - 65 years and over - Male  \
# 0                                        49676.0
# 1                                        61808.0
# 2                                        54456.0
# 3                                        55915.0
# 4                                        59392.0
# ..                                           ...
# 430                                      77436.0
# 431                                      62612.0
# 432                                      88221.0
# 433                                      81831.0
# 434                                      50609.0
#
#      Total population - 65 years and over - Sex ratio (males per 100 females)  \
# 0                                                                       101.9
# 1                                                                        82.8
# 2                                                                        76.9
# 3                                                                        79.6
# 4                                                                        79.6
# ..                                                                        ...
# 430                                                                      93.4
# 431                                                                      87.9
# 432                                                                      83.6
# 433                                                                      87.8
# 434                                                                      95.1
#
#      Total population - 75 to 84 years  Total population - 85 years and over  \
# 0                              24410.0                                6709.0
# 1                              40508.0                               12282.0
# 2                              38134.0                               12806.0
# 3                              39234.0                                8784.0
# 4                              40315.0                               12003.0
# ..                                 ...                                   ...
# 430                            45479.0                               17297.0
# 431                            38348.0                               14223.0
# 432                            55153.0                               19269.0
# 433                            51215.0                               16552.0
# 434                            26372.0                               11032.0
#
#      Total population - Female  Total population - Male  \
# 0                     349552.0                 383121.0
# 1                     373755.0                 353457.0
# 2                     370483.0                 345729.0
# 3                     368853.0                 352436.0
# 4                     369637.0                 353433.0
# ..                         ...                      ...
# 430                   365784.0                 378859.0
# 431                   365825.0                 371023.0
# 432                   447881.0                 434099.0
# 433                   447718.0                 453261.0
# 434                   282796.0                 296007.0
#
#      Total population - Median age (years)  \
# 0                                     35.6
# 1                                     41.0
# 2                                     39.0
# 3                                     40.0
# 4                                     40.5
# ..                                     ...
# 430                                   44.9
# 431                                   41.1
# 432                                   44.0
# 433                                   41.6
# 434                                   39.0
#
#      Total population - Sex ratio (males per 100 females)  \
# 0                                                   109.6
# 1                                                    94.6
# 2                                                    93.3
# 3                                                    95.5
# 4                                                    95.6
# ..                                                    ...
# 430                                                 103.6
# 431                                                 101.4
# 432                                                  96.9
# 433                                                 101.2
# 434                                                 104.7
#
#      Total population - Under 18 years  Total population - Under 5 years
# 0                             179401.0                           46198.0
# 1                             162658.0                           41746.0
# 2                             165222.0                           41997.0
# 3                             152113.0                           39510.0
# 4                             165303.0                           45914.0
# ..                                 ...                               ...
# 430                           157839.0                           36524.0
# 431                           162548.0                           40347.0
# 432                           180487.0                           43443.0
# 433                           180905.0                           45341.0
# 434                           131529.0                           30233.0
#
# [435 rows x 67 columns]
